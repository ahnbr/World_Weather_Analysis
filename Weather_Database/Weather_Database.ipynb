# %%
import requests 
import pandas as pd
import numpy as np
from citipy import citipy

##  import api keys
from config import weather_api_key
from config import g_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Generate a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=04210c4e98be731b35089f9bbea2eb9c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,  
                          "Current Description": city_weather_desc
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | le vauclin
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | saldanha
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | rorvik
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | sao joao del rei
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | yingkou
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | mandalgovi
# Processing Record 25 of Set 1 | coquimbo
# Processing Record 26 of Set 1 | gouyave
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | hoquiam
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | quarai
# Processing Record 31 of Set 1 | norman wells
# Processing Record 32 of Set 1 | broome
# Processing Record 33 of Set 1 | lincoln
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | osoyoos
# Processing Record 36 of Set 1 | qui nhon
# Processing Record 37 of Set 1 | tuatapere
# Processing Record 38 of Set 1 | bubaque
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | tura
# Processing Record 47 of Set 1 | bauchi
# Processing Record 48 of Set 1 | cockburn town
# Processing Record 49 of Set 1 | hailar
# Processing Record 50 of Set 1 | tilichiki
# Processing Record 1 of Set 2 | beyneu
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | makakilo city
# Processing Record 4 of Set 2 | san quintin
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | lodja
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | leeuwarden
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | guerrero negro
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | lazaro cardenas
# Processing Record 15 of Set 2 | faya
# Processing Record 16 of Set 2 | lata
# Processing Record 17 of Set 2 | asosa
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | rawson
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | labuhan
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | paiho
# City not found. Skipping...
# Processing Record 24 of Set 2 | mariana
# Processing Record 25 of Set 2 | la ronge
# Processing Record 26 of Set 2 | port blair
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | port-cartier
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | ixil
# Processing Record 33 of Set 2 | merrimack
# Processing Record 34 of Set 2 | asau
# Processing Record 35 of Set 2 | manicore
# Processing Record 36 of Set 2 | westport
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | bowen
# Processing Record 39 of Set 2 | zabol
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | mgandu
# Processing Record 42 of Set 2 | pachmarhi
# Processing Record 43 of Set 2 | iquitos
# Processing Record 44 of Set 2 | asfi
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | utete
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | saint anthony
# Processing Record 3 of Set 3 | buala
# Processing Record 4 of Set 3 | namie
# Processing Record 5 of Set 3 | charters towers
# Processing Record 6 of Set 3 | kralendijk
# Processing Record 7 of Set 3 | rio grande
# Processing Record 8 of Set 3 | port moresby
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | arani
# Processing Record 11 of Set 3 | rudbar
# Processing Record 12 of Set 3 | jimenez
# Processing Record 13 of Set 3 | pringsewu
# Processing Record 14 of Set 3 | maiduguri
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | moussoro
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | katsuura
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | pa sang
# Processing Record 21 of Set 3 | lephepe
# City not found. Skipping...
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | robat karim
# Processing Record 24 of Set 3 | benicarlo
# Processing Record 25 of Set 3 | meulaboh
# Processing Record 26 of Set 3 | lubango
# Processing Record 27 of Set 3 | lagoa
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | aksarka
# Processing Record 30 of Set 3 | arlit
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | townsend
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | bangui
# Processing Record 36 of Set 3 | santa cruz de tenerife
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | ravar
# Processing Record 39 of Set 3 | cap malheureux
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | ambon
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | along
# Processing Record 45 of Set 3 | pastos bons
# Processing Record 46 of Set 3 | geraldton
# Processing Record 47 of Set 3 | oeiras do para
# Processing Record 48 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 3 | haines junction
# Processing Record 50 of Set 3 | santa maria
# Processing Record 1 of Set 4 | candolim
# Processing Record 2 of Set 4 | tiarei
# Processing Record 3 of Set 4 | kasongo
# Processing Record 4 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 5 of Set 4 | denpasar
# Processing Record 6 of Set 4 | marfino
# Processing Record 7 of Set 4 | namibe
# Processing Record 8 of Set 4 | valparaiso
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 4 | bonavista
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | kulhudhuffushi
# Processing Record 14 of Set 4 | richards bay
# Processing Record 15 of Set 4 | kokkola
# Processing Record 16 of Set 4 | pacifica
# Processing Record 17 of Set 4 | payson
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | carutapera
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 4 | arraial do cabo
# Processing Record 26 of Set 4 | libreville
# Processing Record 27 of Set 4 | hasaki
# Processing Record 28 of Set 4 | mecca
# Processing Record 29 of Set 4 | hervey bay
# Processing Record 30 of Set 4 | san vicente de canete
# Processing Record 31 of Set 4 | palora
# Processing Record 32 of Set 4 | new norfolk
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | mayo
# Processing Record 35 of Set 4 | tahta
# Processing Record 36 of Set 4 | kupang
# Processing Record 37 of Set 4 | amparai
# City not found. Skipping...
# Processing Record 38 of Set 4 | bonthe
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | cangzhou
# Processing Record 41 of Set 4 | minot
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | talcahuano
# Processing Record 44 of Set 4 | christchurch
# Processing Record 45 of Set 4 | berlevag
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | xichang
# Processing Record 48 of Set 4 | chiria
# Processing Record 49 of Set 4 | terre haute
# Processing Record 50 of Set 4 | itarema
# Processing Record 1 of Set 5 | lumphat
# Processing Record 2 of Set 5 | alice springs
# Processing Record 3 of Set 5 | tokmak
# Processing Record 4 of Set 5 | blythe
# Processing Record 5 of Set 5 | sovetskoye
# Processing Record 6 of Set 5 | maracacume
# Processing Record 7 of Set 5 | zaraza
# Processing Record 8 of Set 5 | lompoc
# Processing Record 9 of Set 5 | jalu
# Processing Record 10 of Set 5 | bethel
# Processing Record 11 of Set 5 | nouadhibou
# Processing Record 12 of Set 5 | jakar
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | nuuk
# Processing Record 15 of Set 5 | yeppoon
# Processing Record 16 of Set 5 | waw
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | caravelas
# Processing Record 19 of Set 5 | marsh harbour
# Processing Record 20 of Set 5 | kyotera
# Processing Record 21 of Set 5 | champerico
# Processing Record 22 of Set 5 | cobija
# Processing Record 23 of Set 5 | halifax
# Processing Record 24 of Set 5 | mbini
# Processing Record 25 of Set 5 | cabo san lucas
# Processing Record 26 of Set 5 | port lincoln
# Processing Record 27 of Set 5 | gondar
# Processing Record 28 of Set 5 | soe
# Processing Record 29 of Set 5 | axim
# Processing Record 30 of Set 5 | udachnyy
# Processing Record 31 of Set 5 | ogaminana
# Processing Record 32 of Set 5 | hobyo
# Processing Record 33 of Set 5 | abay
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | porosozero
# Processing Record 36 of Set 5 | kolosovka
# Processing Record 37 of Set 5 | dikson
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | biloela
# Processing Record 40 of Set 5 | nikel
# Processing Record 41 of Set 5 | kjollefjord
# Processing Record 42 of Set 5 | valday
# Processing Record 43 of Set 5 | torbay
# Processing Record 44 of Set 5 | paamiut
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | abalak
# Processing Record 48 of Set 5 | farafangana
# Processing Record 49 of Set 5 | coahuayana
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | kapaa
# Processing Record 2 of Set 6 | palmer
# Processing Record 3 of Set 6 | kandla
# Processing Record 4 of Set 6 | valdosta
# Processing Record 5 of Set 6 | chuy
# Processing Record 6 of Set 6 | sangolqui
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | fairbanks
# Processing Record 9 of Set 6 | betsiamites
# Processing Record 10 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 6 | ugoofaaru
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | leningradskiy
# Processing Record 14 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 15 of Set 6 | amapa
# Processing Record 16 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 6 | puerto escondido
# Processing Record 18 of Set 6 | suez
# Processing Record 19 of Set 6 | kaberamaido
# Processing Record 20 of Set 6 | rodrigues alves
# Processing Record 21 of Set 6 | newport
# Processing Record 22 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | cherskiy
# Processing Record 24 of Set 6 | ayacucho
# Processing Record 25 of Set 6 | innisfail
# Processing Record 26 of Set 6 | mitsamiouli
# Processing Record 27 of Set 6 | itaituba
# Processing Record 28 of Set 6 | seoul
# Processing Record 29 of Set 6 | talnakh
# Processing Record 30 of Set 6 | azare
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | north bend
# Processing Record 33 of Set 6 | porto real
# Processing Record 34 of Set 6 | vestmannaeyjar
# Processing Record 35 of Set 6 | pangai
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | salalah
# Processing Record 38 of Set 6 | plettenberg bay
# Processing Record 39 of Set 6 | kahului
# Processing Record 40 of Set 6 | anloga
# Processing Record 41 of Set 6 | hof
# Processing Record 42 of Set 6 | ahuimanu
# Processing Record 43 of Set 6 | hobbs
# Processing Record 44 of Set 6 | hit
# Processing Record 45 of Set 6 | hami
# Processing Record 46 of Set 6 | maniitsoq
# Processing Record 47 of Set 6 | wadi maliz
# Processing Record 48 of Set 6 | sulangan
# Processing Record 49 of Set 6 | benghazi
# Processing Record 50 of Set 6 | provideniya
# Processing Record 1 of Set 7 | leticia
# Processing Record 2 of Set 7 | olafsvik
# Processing Record 3 of Set 7 | skibbereen
# Processing Record 4 of Set 7 | bani walid
# Processing Record 5 of Set 7 | ulladulla
# Processing Record 6 of Set 7 | chomun
# City not found. Skipping...
# Processing Record 7 of Set 7 | high level
# Processing Record 8 of Set 7 | necochea
# Processing Record 9 of Set 7 | kuznechnoye
# Processing Record 10 of Set 7 | nhulunbuy
# Processing Record 11 of Set 7 | prince rupert
# Processing Record 12 of Set 7 | arsk
# Processing Record 13 of Set 7 | surt
# Processing Record 14 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 7 | maroantsetra
# Processing Record 16 of Set 7 | sarandi
# Processing Record 17 of Set 7 | melville
# Processing Record 18 of Set 7 | marawi
# Processing Record 19 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 7 | manavalakurichi
# Processing Record 21 of Set 7 | praia da vitoria
# Processing Record 22 of Set 7 | touros
# Processing Record 23 of Set 7 | adrar
# Processing Record 24 of Set 7 | port hardy
# Processing Record 25 of Set 7 | laurinburg
# Processing Record 26 of Set 7 | kampot
# Processing Record 27 of Set 7 | ponta delgada
# Processing Record 28 of Set 7 | chepareria
# Processing Record 29 of Set 7 | peniche
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | fare
# Processing Record 32 of Set 7 | nioro
# Processing Record 33 of Set 7 | atascadero
# Processing Record 34 of Set 7 | aklavik
# Processing Record 35 of Set 7 | hermanuv mestec
# Processing Record 36 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 7 | gornopravdinsk
# Processing Record 38 of Set 7 | bellavista
# Processing Record 39 of Set 7 | mana
# Processing Record 40 of Set 7 | sagua de tanamo
# Processing Record 41 of Set 7 | kavaratti
# Processing Record 42 of Set 7 | dunedin
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | bandundu
# Processing Record 45 of Set 7 | san patricio
# Processing Record 46 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 7 | kutum
# Processing Record 48 of Set 7 | havoysund
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | santa rosa
# Processing Record 1 of Set 8 | yumen
# Processing Record 2 of Set 8 | tautira
# Processing Record 3 of Set 8 | evensk
# Processing Record 4 of Set 8 | farah
# Processing Record 5 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 8 | salumbar
# Processing Record 7 of Set 8 | saint-francois
# Processing Record 8 of Set 8 | bandarbeyla
# Processing Record 9 of Set 8 | hamilton
# Processing Record 10 of Set 8 | tessalit
# Processing Record 11 of Set 8 | thunder bay
# Processing Record 12 of Set 8 | tsaratanana
# Processing Record 13 of Set 8 | copiapo
# Processing Record 14 of Set 8 | ocampo
# Processing Record 15 of Set 8 | dayong
# Processing Record 16 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 8 | hirakud
# Processing Record 18 of Set 8 | sechelt
# Processing Record 19 of Set 8 | erzin
# Processing Record 20 of Set 8 | zhuhai
# Processing Record 21 of Set 8 | aykhal
# Processing Record 22 of Set 8 | manono
# Processing Record 23 of Set 8 | comodoro rivadavia
# Processing Record 24 of Set 8 | mananjary
# Processing Record 25 of Set 8 | sibolga
# Processing Record 26 of Set 8 | santa maria del oro
# Processing Record 27 of Set 8 | hay river
# Processing Record 28 of Set 8 | port-gentil
# Processing Record 29 of Set 8 | porto murtinho
# Processing Record 30 of Set 8 | vetluzhskiy
# Processing Record 31 of Set 8 | sobolevo
# Processing Record 32 of Set 8 | calama
# Processing Record 33 of Set 8 | manaus
# Processing Record 34 of Set 8 | banda aceh
# Processing Record 35 of Set 8 | kavieng
# Processing Record 36 of Set 8 | miyako
# Processing Record 37 of Set 8 | we
# City not found. Skipping...
# Processing Record 38 of Set 8 | irbil
# Processing Record 39 of Set 8 | nizwa
# Processing Record 40 of Set 8 | santa vitoria do palmar
# Processing Record 41 of Set 8 | conselheiro pena
# Processing Record 42 of Set 8 | henties bay
# Processing Record 43 of Set 8 | sorland
# Processing Record 44 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 45 of Set 8 | chiredzi
# Processing Record 46 of Set 8 | wewak
# Processing Record 47 of Set 8 | honningsvag
# Processing Record 48 of Set 8 | kerchevskiy
# Processing Record 49 of Set 8 | bull savanna
# Processing Record 50 of Set 8 | half moon bay
# Processing Record 1 of Set 9 | auki
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | rio gallegos
# Processing Record 4 of Set 9 | unye
# City not found. Skipping...
# Processing Record 5 of Set 9 | neufchateau
# Processing Record 6 of Set 9 | statesville
# Processing Record 7 of Set 9 | namtsy
# Processing Record 8 of Set 9 | sumbe
# Processing Record 9 of Set 9 | kailua
# Processing Record 10 of Set 9 | rach gia
# Processing Record 11 of Set 9 | portel
# Processing Record 12 of Set 9 | lookan
# Processing Record 13 of Set 9 | laredo
# Processing Record 14 of Set 9 | vigeland
# Processing Record 15 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 9 | zemio
# Processing Record 17 of Set 9 | joensuu
# Processing Record 18 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 19 of Set 9 | maceio
# Processing Record 20 of Set 9 | lakheri
# Processing Record 21 of Set 9 | sao joao da barra
# Processing Record 22 of Set 9 | samarai
# Processing Record 23 of Set 9 | itoman
# Processing Record 24 of Set 9 | tigil
# Processing Record 25 of Set 9 | mogochin
# City not found. Skipping...
# Processing Record 26 of Set 9 | pestera
# Processing Record 27 of Set 9 | marystown
# Processing Record 28 of Set 9 | sungairaya
# Processing Record 29 of Set 9 | pozo colorado
# Processing Record 30 of Set 9 | miquelon
# Processing Record 31 of Set 9 | maturin
# Processing Record 32 of Set 9 | tomaszow mazowiecki
# Processing Record 33 of Set 9 | idil
# Processing Record 34 of Set 9 | fengcheng
# Processing Record 35 of Set 9 | labuan
# Processing Record 36 of Set 9 | wamba
# Processing Record 37 of Set 9 | camacha
# Processing Record 38 of Set 9 | lac du bonnet
# Processing Record 39 of Set 9 | maniago
# Processing Record 40 of Set 9 | demba
# Processing Record 41 of Set 9 | khurda
# Processing Record 42 of Set 9 | aksu
# Processing Record 43 of Set 9 | vilyuysk
# Processing Record 44 of Set 9 | ranong
# Processing Record 45 of Set 9 | coolum beach
# Processing Record 46 of Set 9 | singaraja
# Processing Record 47 of Set 9 | kaputa
# Processing Record 48 of Set 9 | olavarria
# Processing Record 49 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 9 | lovozero
# Processing Record 1 of Set 10 | tondano
# Processing Record 2 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 3 of Set 10 | hun
# Processing Record 4 of Set 10 | vila franca do campo
# Processing Record 5 of Set 10 | banjar
# Processing Record 6 of Set 10 | takoradi
# Processing Record 7 of Set 10 | qasigiannguit
# Processing Record 8 of Set 10 | tiznit
# Processing Record 9 of Set 10 | sabha
# Processing Record 10 of Set 10 | jiuquan
# Processing Record 11 of Set 10 | sydney
# Processing Record 12 of Set 10 | coihaique
# Processing Record 13 of Set 10 | yacuiba
# Processing Record 14 of Set 10 | hailakandi
# Processing Record 15 of Set 10 | grand gaube
# Processing Record 16 of Set 10 | wagar
# Processing Record 17 of Set 10 | sorong
# Processing Record 18 of Set 10 | oriximina
# Processing Record 19 of Set 10 | tual
# Processing Record 20 of Set 10 | lhokseumawe
# Processing Record 21 of Set 10 | whitehaven
# Processing Record 22 of Set 10 | klaksvik
# Processing Record 23 of Set 10 | warrnambool
# Processing Record 24 of Set 10 | malakal
# Processing Record 25 of Set 10 | harper
# Processing Record 26 of Set 10 | tongliao
# Processing Record 27 of Set 10 | bedworth
# Processing Record 28 of Set 10 | tombouctou
# Processing Record 29 of Set 10 | chitral
# Processing Record 30 of Set 10 | ust-kan
# Processing Record 31 of Set 10 | saint-georges
# Processing Record 32 of Set 10 | zhicheng
# Processing Record 33 of Set 10 | saint-pierre
# Processing Record 34 of Set 10 | puerto ayacucho
# Processing Record 35 of Set 10 | ulety
# Processing Record 36 of Set 10 | pareora
# Processing Record 37 of Set 10 | palaiokhora
# City not found. Skipping...
# Processing Record 38 of Set 10 | matara
# Processing Record 39 of Set 10 | wloclawek
# Processing Record 40 of Set 10 | balikpapan
# Processing Record 41 of Set 10 | mongu
# Processing Record 42 of Set 10 | sembe
# Processing Record 43 of Set 10 | olga
# Processing Record 44 of Set 10 | chambas
# Processing Record 45 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 10 | sambava
# Processing Record 48 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 10 | okhotsk
# Processing Record 50 of Set 10 | andenes
# Processing Record 1 of Set 11 | carupano
# Processing Record 2 of Set 11 | kushmurun
# Processing Record 3 of Set 11 | yerbogachen
# Processing Record 4 of Set 11 | granada
# Processing Record 5 of Set 11 | los banos
# Processing Record 6 of Set 11 | kikwit
# Processing Record 7 of Set 11 | karachi
# Processing Record 8 of Set 11 | nishihara
# Processing Record 9 of Set 11 | lahaina
# Processing Record 10 of Set 11 | dabola
# Processing Record 11 of Set 11 | sao filipe
# Processing Record 12 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 11 | omboue
# Processing Record 14 of Set 11 | am timan
# Processing Record 15 of Set 11 | soyo
# Processing Record 16 of Set 11 | menongue
# Processing Record 17 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 11 | broken hill
# Processing Record 19 of Set 11 | medea
# Processing Record 20 of Set 11 | puerto carreno
# Processing Record 21 of Set 11 | spring hill
# Processing Record 22 of Set 11 | dicabisagan
# Processing Record 23 of Set 11 | isla vista
# Processing Record 24 of Set 11 | santa lucia
# Processing Record 25 of Set 11 | bilibino
# Processing Record 26 of Set 11 | velden am worthersee
# Processing Record 27 of Set 11 | bonao
# Processing Record 28 of Set 11 | sisophon
# Processing Record 29 of Set 11 | margate
# Processing Record 30 of Set 11 | hudson
# Processing Record 31 of Set 11 | port pirie
# Processing Record 32 of Set 11 | alyangula
# Processing Record 33 of Set 11 | jardim
# Processing Record 34 of Set 11 | plavsk
# Processing Record 35 of Set 11 | sola
# Processing Record 36 of Set 11 | kochevo
# Processing Record 37 of Set 11 | vila do maio
# Processing Record 38 of Set 11 | tromso
# Processing Record 39 of Set 11 | iguape
# Processing Record 40 of Set 11 | miles city
# Processing Record 41 of Set 11 | pirovskoye
# Processing Record 42 of Set 11 | boshnyakovo
# Processing Record 43 of Set 11 | krasnoselkup
# Processing Record 44 of Set 11 | kamenka
# Processing Record 45 of Set 11 | hambantota
# Processing Record 46 of Set 11 | goure
# Processing Record 47 of Set 11 | naranjal
# Processing Record 48 of Set 11 | nchelenge
# Processing Record 49 of Set 11 | njeru
# Processing Record 50 of Set 11 | los llanos de aridane
# Processing Record 1 of Set 12 | waipawa
# Processing Record 2 of Set 12 | ballina
# Processing Record 3 of Set 12 | puro
# Processing Record 4 of Set 12 | nanortalik
# Processing Record 5 of Set 12 | kabare
# Processing Record 6 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 12 | ucluelet
# Processing Record 8 of Set 12 | sept-iles
# Processing Record 9 of Set 12 | emerald
# Processing Record 10 of Set 12 | hastings
# Processing Record 11 of Set 12 | tunceli
# Processing Record 12 of Set 12 | te anau
# Processing Record 13 of Set 12 | faanui
# Processing Record 14 of Set 12 | yaan
# Processing Record 15 of Set 12 | beringovskiy
# Processing Record 16 of Set 12 | bismarck
# Processing Record 17 of Set 12 | kuruman
# Processing Record 18 of Set 12 | camabatela
# Processing Record 19 of Set 12 | houma
# Processing Record 20 of Set 12 | issia
# Processing Record 21 of Set 12 | sao jose da coroa grande
# Processing Record 22 of Set 12 | souillac
# Processing Record 23 of Set 12 | saint-leu
# Processing Record 24 of Set 12 | da lat
# Processing Record 25 of Set 12 | zilair
# Processing Record 26 of Set 12 | chacabuco
# Processing Record 27 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 12 | sheridan
# Processing Record 29 of Set 12 | caribou
# Processing Record 30 of Set 12 | hofn
# Processing Record 31 of Set 12 | avera
# Processing Record 32 of Set 12 | high prairie
# Processing Record 33 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 12 | wenling
# Processing Record 37 of Set 12 | bonfim
# Processing Record 38 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 12 | malaga
# Processing Record 40 of Set 12 | yamada
# Processing Record 41 of Set 12 | mtinko
# Processing Record 42 of Set 12 | beaverlodge
# Processing Record 43 of Set 12 | boa vista
# Processing Record 44 of Set 12 | urucara
# Processing Record 45 of Set 12 | pasighat
# Processing Record 46 of Set 12 | chestermere
# Processing Record 47 of Set 12 | taoudenni
# Processing Record 48 of Set 12 | kurchum
# Processing Record 49 of Set 12 | husavik
# Processing Record 50 of Set 12 | isiro
# Processing Record 1 of Set 13 | anadyr
# Processing Record 2 of Set 13 | mareeba
# Processing Record 3 of Set 13 | santa cruz
# Processing Record 4 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 13 | yeniseysk
# Processing Record 6 of Set 13 | pimentel
# Processing Record 7 of Set 13 | do rud
# City not found. Skipping...
# Processing Record 8 of Set 13 | santa vitoria
# Processing Record 9 of Set 13 | chanal
# Processing Record 10 of Set 13 | le chambon-feugerolles
# Processing Record 11 of Set 13 | kieta
# Processing Record 12 of Set 13 | san ramon
# Processing Record 13 of Set 13 | riyadh
# Processing Record 14 of Set 13 | horsham
# Processing Record 15 of Set 13 | srednekolymsk
# Processing Record 16 of Set 13 | vorotynets
# Processing Record 17 of Set 13 | makokou
# Processing Record 18 of Set 13 | longjiang
# Processing Record 19 of Set 13 | sioux lookout
# Processing Record 20 of Set 13 | ylivieska
# Processing Record 21 of Set 13 | palembang
# Processing Record 22 of Set 13 | chirongui
# Processing Record 23 of Set 13 | batagay
# Processing Record 24 of Set 13 | waingapu
# Processing Record 25 of Set 13 | cody
# Processing Record 26 of Set 13 | priladozhskiy
# Processing Record 27 of Set 13 | turukhansk
# Processing Record 28 of Set 13 | verkhniy mamon
# Processing Record 29 of Set 13 | taperoa
# Processing Record 30 of Set 13 | the pas
# Processing Record 31 of Set 13 | erdenet
# Processing Record 32 of Set 13 | fengrun
# Processing Record 33 of Set 13 | honiara
# Processing Record 34 of Set 13 | charlestown
# Processing Record 35 of Set 13 | cabo rojo
# Processing Record 36 of Set 13 | bobonong
# City not found. Skipping...
# Processing Record 37 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 38 of Set 13 | san miguel
# Processing Record 39 of Set 13 | wuwei
# Processing Record 40 of Set 13 | west wendover
# Processing Record 41 of Set 13 | mumford
# Processing Record 42 of Set 13 | bend
# Processing Record 43 of Set 13 | kuytun
# Processing Record 44 of Set 13 | namatanai
# Processing Record 45 of Set 13 | shahreza
# Processing Record 46 of Set 13 | cruzeiro do sul
# Processing Record 47 of Set 13 | santa fe do sul
# Processing Record 48 of Set 13 | elat
# Processing Record 49 of Set 13 | tarko-sale
# Processing Record 50 of Set 13 | twin falls
# Processing Record 1 of Set 14 | turinsk
# Processing Record 2 of Set 14 | codrington
# Processing Record 3 of Set 14 | portobelo
# Processing Record 4 of Set 14 | roald
# Processing Record 5 of Set 14 | kedrovyy
# Processing Record 6 of Set 14 | salinas
# Processing Record 7 of Set 14 | qazax
# Processing Record 8 of Set 14 | wolmaranstad
# City not found. Skipping...
# Processing Record 9 of Set 14 | barcelos
# Processing Record 10 of Set 14 | kleck
# City not found. Skipping...
# Processing Record 11 of Set 14 | genhe
# Processing Record 12 of Set 14 | shingu
# Processing Record 13 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 14 | shimoda
# Processing Record 15 of Set 14 | ossora
# Processing Record 16 of Set 14 | opuwo
# Processing Record 17 of Set 14 | neiafu
# Processing Record 18 of Set 14 | kayerkan
# Processing Record 19 of Set 14 | chara
# Processing Record 20 of Set 14 | kasongo-lunda
# Processing Record 21 of Set 14 | kalmunai
# Processing Record 22 of Set 14 | luganville
# Processing Record 23 of Set 14 | el centro
# Processing Record 24 of Set 14 | saint-joseph
# Processing Record 25 of Set 14 | dzheguta
# Processing Record 26 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 14 | mitzic
# Processing Record 28 of Set 14 | kudahuvadhoo
# Processing Record 29 of Set 14 | dryden
# Processing Record 30 of Set 14 | lethem
# Processing Record 31 of Set 14 | kovdor
# Processing Record 32 of Set 14 | ouesso
# Processing Record 33 of Set 14 | lobito
# Processing Record 34 of Set 14 | mandaguari
# Processing Record 35 of Set 14 | alekseyevsk
# Processing Record 36 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 37 of Set 14 | joutseno
# Processing Record 38 of Set 14 | musoma
# Processing Record 39 of Set 14 | constitucion
# Processing Record 40 of Set 14 | bahua
# Processing Record 41 of Set 14 | hope
# Processing Record 42 of Set 14 | epe
# Processing Record 43 of Set 14 | batticaloa
# Processing Record 44 of Set 14 | olinda
# Processing Record 45 of Set 14 | kota bahru
# Processing Record 46 of Set 14 | gualaquiza
# Processing Record 47 of Set 14 | aripuana
# Processing Record 48 of Set 14 | asyut
# Processing Record 49 of Set 14 | kumta
# Processing Record 50 of Set 14 | turayf
# Processing Record 1 of Set 15 | praia
# Processing Record 2 of Set 15 | vuktyl
# Processing Record 3 of Set 15 | sol-iletsk
# Processing Record 4 of Set 15 | moron
# Processing Record 5 of Set 15 | college
# Processing Record 6 of Set 15 | mixtepec
# City not found. Skipping...
# Processing Record 7 of Set 15 | labrea
# Processing Record 8 of Set 15 | vukovar
# Processing Record 9 of Set 15 | anstruther
# Processing Record 10 of Set 15 | hualmay
# Processing Record 11 of Set 15 | tucuman
# Processing Record 12 of Set 15 | irtyshskiy
# Processing Record 13 of Set 15 | abu samrah
# Processing Record 14 of Set 15 | yulara
# Processing Record 15 of Set 15 | panorama
# Processing Record 16 of Set 15 | manta
# Processing Record 17 of Set 15 | kloulklubed
# Processing Record 18 of Set 15 | ola
# Processing Record 19 of Set 15 | leskovac
# Processing Record 20 of Set 15 | nelson bay
# Processing Record 21 of Set 15 | marsabit
# Processing Record 22 of Set 15 | lima
# Processing Record 23 of Set 15 | tezu
# Processing Record 24 of Set 15 | topolobampo
# Processing Record 25 of Set 15 | gravdal
# Processing Record 26 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 27 of Set 15 | perth
# Processing Record 28 of Set 15 | angra
# City not found. Skipping...
# Processing Record 29 of Set 15 | chkalovsk
# Processing Record 30 of Set 15 | nemuro
# Processing Record 31 of Set 15 | liepaja
# Processing Record 32 of Set 15 | ocosingo
# Processing Record 33 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 15 | rincon
# Processing Record 35 of Set 15 | chapais
# Processing Record 36 of Set 15 | port augusta
# Processing Record 37 of Set 15 | muros
# Processing Record 38 of Set 15 | flinders
# Processing Record 39 of Set 15 | banjarmasin
# Processing Record 40 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 41 of Set 15 | ahipara
# Processing Record 42 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 15 | ust-tsilma
# Processing Record 44 of Set 15 | porto novo
# Processing Record 45 of Set 15 | laguna de perlas
# Processing Record 46 of Set 15 | malinyi
# Processing Record 47 of Set 15 | karratha
# Processing Record 48 of Set 15 | homer
# Processing Record 49 of Set 15 | adeje
# Processing Record 50 of Set 15 | severnyy
# Processing Record 1 of Set 16 | kelowna
# Processing Record 2 of Set 16 | el rosario
# Processing Record 3 of Set 16 | ulaanbaatar
# Processing Record 4 of Set 16 | quang ngai
# Processing Record 5 of Set 16 | wanning
# Processing Record 6 of Set 16 | sao pedro
# Processing Record 7 of Set 16 | tynda
# Processing Record 8 of Set 16 | puri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Avarua -21.21 -159.78     75.20        73          97        9.17
# 1            Lebu -37.62  -73.65     51.17        68           0       18.21
# 2      Le Vauclin  14.55  -60.84     81.00        88          32        3.36
# 3     East London -33.02   27.91     63.30        57          69        8.39
# 4         Rikitea -23.12 -134.97     73.58        84           0       13.62
# 5          Albany  42.60  -73.97     73.99        65          65        6.58
# 6           Pevek  69.70  170.31     42.49        84          94        8.41
# 7        Saldanha -33.01   17.94     55.40        82          82        3.36
# 8          Barrow  71.29 -156.79     39.20        93          90       18.34
# 9  Ribeira Grande  38.52  -28.70     73.40        83          40       14.99
#
#   Country                 Date Current Description
# 0      CK  2020-09-13 20:35:30     overcast clouds
# 1      CL  2020-09-13 20:35:31           clear sky
# 2      MQ  2020-09-13 20:35:31                mist
# 3      ZA  2020-09-13 20:35:31       broken clouds
# 4      PF  2020-09-13 20:35:31           clear sky
# 5      US  2020-09-13 20:35:31       broken clouds
# 6      RU  2020-09-13 20:31:06     overcast clouds
# 7      ZA  2020-09-13 20:35:31       broken clouds
# 8      US  2020-09-13 20:35:32                mist
# 9      PT  2020-09-13 20:35:32    scattered clouds

# %%
new_column_order = ["City", "Country", "Date","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0          Avarua      CK  2020-09-13 20:35:30 -21.21 -159.78     75.20
# 1            Lebu      CL  2020-09-13 20:35:31 -37.62  -73.65     51.17
# 2      Le Vauclin      MQ  2020-09-13 20:35:31  14.55  -60.84     81.00
# 3     East London      ZA  2020-09-13 20:35:31 -33.02   27.91     63.30
# 4         Rikitea      PF  2020-09-13 20:35:31 -23.12 -134.97     73.58
# 5          Albany      US  2020-09-13 20:35:31  42.60  -73.97     73.99
# 6           Pevek      RU  2020-09-13 20:31:06  69.70  170.31     42.49
# 7        Saldanha      ZA  2020-09-13 20:35:31 -33.01   17.94     55.40
# 8          Barrow      US  2020-09-13 20:35:32  71.29 -156.79     39.20
# 9  Ribeira Grande      PT  2020-09-13 20:35:32  38.52  -28.70     73.40
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        73          97        9.17     overcast clouds
# 1        68           0       18.21           clear sky
# 2        88          32        3.36                mist
# 3        57          69        8.39       broken clouds
# 4        84           0       13.62           clear sky
# 5        65          65        6.58       broken clouds
# 6        84          94        8.41     overcast clouds
# 7        82          82        3.36       broken clouds
# 8        93          90       18.34                mist
# 9        83          40       14.99    scattered clouds

# %%
# Output the content to a CSV file
output_data_file = "weather_data/Weather_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
